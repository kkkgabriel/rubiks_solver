# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit

# %%
# cube

# %% [markdown]
# # positive case

# %%
# util to find numbering
#        u            r           f           d           l           b
s = ['nnnnnnnny','bnnbnnnnn','nnrnnrnnn','nnnnnnnnn','nnnnnnnnn','nnnnnnnnn',]
s = ''.join(s)
c = cube(colours=s)
c.view()
c.E()
c.view()
c.Ep()
c.Ep()
c.view()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC82253C8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC8225948>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC8225A48>

# %% [markdown]
# # negative

# %%
# util to find numbering
#        u            r           f           d           l           b
s = ['nnnnnnnnr','ynnbnnnnn','nnbnnrnnn','nnnnnnnnn','nnnnnnnnn','nnnnnnnnn',]
s = ''.join(s)
c = cube(colours=s)
c.view()
c.E()
c.view()
c.Ep()
c.Ep()
c.view()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC8229548>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC8229D08>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x20DC8229348>
