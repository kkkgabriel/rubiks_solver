# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit

# %%
# util to find numbering
#        u            r           f           d           l           b
# s = ['nnnnynnnn','nnnnrnnnn','nnnnbnnnn','nnwnwwnnw','nnnnonnnn','nngnggnng',]
# s = ''.join(s)
# c = cube(colours=s)
c = cube()
# c.move("F U R U' R' F'")
m =  "F U R U' R' F'"
m += " F"
# m += " F R U R' U' F'"
c.move(m)
c.view()
c.view(bottom=True)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x263BC191488>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x263BC191A88>
