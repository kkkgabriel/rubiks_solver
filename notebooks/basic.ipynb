# %%
from rubiks import *

# %%
# test 1
c = cube()
c.move("R' U L D R")
c.view()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1C6A382DE48>

# %%
# test 2
c = cube()
c.move("B B L' B' R D' U'")
c.view()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1C6A382D748>
