# %% [markdown]
# ### Changes since test6
# - new heuristic: compound2

# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit

# %% [markdown]
# ## Test

# %%
steps = 5
eps = 5
maxDepth = 5

# %%
time = 0
solved = 0
for i in range(eps):
    
    moves = generateScramble(steps) # 4 move scramble
    c = cube()
    c.move(moves)
    print(moves)
    c.view()
    
    s = solver(c, h=compound2)
    start = timeit.default_timer()
    s.solve(maxDepth=maxDepth)
    if s.solutionFound:
        solved +=1
    stop = timeit.default_timer()
    timeTaken = stop - start
    time += timeTaken
    print('Time: ', timeTaken)
    print('=================================\n')
    
print('Average time taken: {}'.format(timeTaken/eps))
print('Solved: {}/{}'.format(solved, eps))
# Out:
# F' F F' F' B
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB874C48>
# The starting score of the cube is : 52.0
# The next score of the cube is : 52.0
# The next score of the cube is : 65.0
# The next score of the cube is : 52.0
# The next score of the cube is : 62.0
# The next score of the cube is : 84.0
# Found Solution!
# ['F', 'F', "B'"]
# Time:  0.006434300000002224
# =================================
#
# U D L B' D'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB879288>
# The starting score of the cube is : 31.5
# The next score of the cube is : 31.5
# The next score of the cube is : 35.0
# The next score of the cube is : 38.0
# The next score of the cube is : 41.0
# The next score of the cube is : 42.0
# The next score of the cube is : 34.5
# The next score of the cube is : 38.0
# The next score of the cube is : 41.0
# The next score of the cube is : 42.0
# The next score of the cube is : 37.0
# The next score of the cube is : 43.0
# The next score of the cube is : 48.5
# The next score of the cube is : 43.5
# The next score of the cube is : 42.5
# The next score of the cube is : 48.5
# The next score of the cube is : 39.0
# The next score of the cube is : 43.5
# Oh no no more item in the queue
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB874308>
# Max score in iteration: 48.5
# ['D', "L'", "U'", "D'"]
# No solution found
# Time:  0.6995693000000003
# =================================
#
# F B' U F F'
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB879548>
# The starting score of the cube is : 44.0
# The next score of the cube is : 44.0
# The next score of the cube is : 52.0
# The next score of the cube is : 62.0
# The next score of the cube is : 84.0
# Found Solution!
# ["U'", "F'", 'B']
# Time:  0.004277000000001863
# =================================
#
# F' U' F F' B
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB879A08>
# The starting score of the cube is : 35.0
# The next score of the cube is : 35.0
# The next score of the cube is : 51.5
# The next score of the cube is : 62.0
# The next score of the cube is : 84.0
# Found Solution!
# ["B'", 'U', 'F']
# Time:  0.006276799999994864
# =================================
#
# F' B R U R
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x1FABB8739C8>
# The starting score of the cube is : 28.0
# The next score of the cube is : 28.0
# The next score of the cube is : 35.5
# The next score of the cube is : 36.5
# The next score of the cube is : 37.0
# The next score of the cube is : 36.5
# The next score of the cube is : 41.5
# The next score of the cube is : 35.5
# The next score of the cube is : 36.0
# The next score of the cube is : 34.0
# The next score of the cube is : 29.0
# The next score of the cube is : 36.0
# The next score of the cube is : 44.5
# The next score of the cube is : 46.5
# The next score of the cube is : 37.5
