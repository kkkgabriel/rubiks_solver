# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit

# %%
# util to find numbering
#        u            r           f           d           l           b
# s = ['nnnnynnnn','nnnnrnnnn','nnnnbnnnn','nnwnwwnnw','nnnnonnnn','nngnggnng',]
# s = ''.join(s)
# c = cube(colours=s)
c = cube()
c.R()
for i in range(5):
    print('===================')
    c.D()
    c.view(bottom=True)
    c.view_right(bottom=True)
    c.view_back(bottom=True)
    c.view_left(bottom=True)
# Out:
# ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76730708>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76730808>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754088>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754188>
# ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754388>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754288>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754208>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D7673CF08>
# ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754508>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D7673CC08>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754408>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x11D76754408>
# ...
