# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit
import pandas as pd

# %%
h = {
    "numberOfCorrectColorsOnFace": numberOfCorrectColorsOnFace,
    "numberOfPairedCornerNEdges": numberOfPairedCornerNEdges,
    "oneStepCornerEdgePair": oneStepCornerEdgePair,
    "compound1": compound1,
    "compound2": compound2
}

# %%
all_steps = [3,5,7,10]
eps = 20
results = {}

# %%
# make scrambles
scrambles = []
for steps in all_steps:
    scrambles += [generateScramble(steps) for ep in range(eps)]

# %%
for heuristic in h.items():
    result = {}
    for n, steps in enumerate(all_steps):
        time = 0
        solved = 0
        for i in range(eps):
            scramble = scrambles[eps*n + i]
            c = cube()
            c.move(scramble)

            s = solver(c, h=heuristic[1])
            start = timeit.default_timer()
            s.solve(maxDepth=steps, display=False, verbose=False, earlyTermination=500)
            if s.solutionFound:
                solved +=1
            stop = timeit.default_timer()
            timeTaken = stop - start
            time += timeTaken
            
        avg_time = time/eps
        result['{}_steps_avg_time'.format(steps)] = avg_time
        result['{}_steps_solves (%)'.format(steps)] = (solved/eps) * 100
    results[heuristic[0]] = result

# %%
pd.DataFrame.from_dict(results, orient='index')
# Out:
#                              3_steps_avg_time  3_steps_solves (%)  \
# numberOfCorrectColorsOnFace          0.002220                95.0
# numberOfPairedCornerNEdges           0.002110               100.0
# oneStepCornerEdgePair                0.058089                85.0
# compound1                            0.003752                95.0
# compound2                            0.003305                95.0
#
#                              5_steps_avg_time  5_steps_solves (%)  \
# numberOfCorrectColorsOnFace          0.035122                70.0
# numberOfPairedCornerNEdges           0.039653                75.0
# oneStepCornerEdgePair                2.897277                35.0
# compound1                            0.090132                55.0
# compound2                            0.087563                60.0
#
#                              7_steps_avg_time  7_steps_solves (%)  \
# numberOfCorrectColorsOnFace          0.123659                35.0
# numberOfPairedCornerNEdges           0.066154                60.0
# oneStepCornerEdgePair                2.907630                20.0
# compound1                            0.122964                45.0
# compound2                            0.147871                40.0
#
#                              10_steps_avg_time  10_steps_solves (%)
# numberOfCorrectColorsOnFace           0.168515                  5.0
# numberOfPairedCornerNEdges            0.226127                 35.0
# oneStepCornerEdgePair                 6.626005                  0.0
# compound1                             0.450881                 25.0
# compound2                             0.383967                 30.0
