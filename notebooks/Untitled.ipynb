# %%
from rubiks import *
from solver import *
from heuristics import *
import timeit
import pandas as pd

# %%
#        u            r           f           d           l           b
s = ['nnnnnnnnn','nnnnnnnnn','nnnnnnnnn','nnnnnnnnn','nnnnnnnnn','nnnnnnnnn',]
s = ''.join(s)
c = cube()

# %%
c.view()
c.view(bottom=True)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x272227F4988>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x272227F4988>

# %%
s = solver(c, numberOfCorrectColorsOnFace)

# %%
s.solve()
# Out:
# The starting score of the cube is : 42
# The next score of the cube is : 42
# The next score of the cube is : 54
# Found Solution!
# ["U'"]
